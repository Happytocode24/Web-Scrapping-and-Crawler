# %%
import pandas as pd
df= pd.read_csv("RP_webscrap.csv",engine='python')
n=len(df['Paper'])
print(n)
i=0
while(i<n):
    j=i+1
    
    while(j<n):
            if (df.Paper[i]==df.Paper[j]) or (df.Names[i]==df.Names[j]):
                break
            elif df.Paper[i]!=df.Paper[j] and (df.Names[i]!=df.Names[j]):
                j=j+1
                if j==n :   
                    print(df.Paper[i])
              
    i=i+1 
df.to_csv("Filtered.csv")
# Out:
# 331
# Measuring college students' sleep, stress, mental health and wellbeing with wearable sensors and mobile phones
# EasyBand: a wearable for safety-aware mobility during pandemic outbreak
# A systematic review of wearable patient monitoring systems–current challenges and opportunities for clinical adoption
# Ensuring wearable devices don't wear out their welcome: Cautions for the mental health care road ahead.
# Wearable mental-health monitoring platform with independent component analysis and nonlinear chaotic analysis
# Mental state recognition via wearable eeg
# Transfer learning for wearable long-term social speech evaluations
# Healthwear: medical technology becomes wearable
# [HTML][HTML] Quantified Self-Using Consumer Wearable Device: Predicting Physical and Mental Health
# Wearable long-term social sensing for mental wellbeing
# Attention-block deep learning based features fusion in wearable social sensor for mental wellbeing evaluations
# Wearable 3.0: From Smart Clothing to Wearable Affective Robot
# Deep learning with wearable based heart rate variability for prediction of mental and general health
# Roll-over detection and sleep quality measurement using a wearable sensor
# IoT structured long-term wearable social sensing for mental wellbeing
# A wearable EEG-HEG-HRV multimodal system with simultaneous monitoring of tES for mental health management
# Recognizing academic performance, sleep quality, stress level, and mental health using personality traits, wearable sensors and mobile phones
# [HTML][HTML] Identifying objective physiological markers and modifiable behaviors for self-reported stress and mental health status using wearable sensors and mobile …
# Perceived acceptability of wearable devices for the treatment of mental health problems
# Objective assessment of depressive symptoms with machine learning and wearable sensors data
# A wearable electrochemical sensing system for non-invasive monitoring of lithium drug in bipolar disorder
# [HTML][HTML] Alcohol use disorder in the age of technology: a review of wearable biosensors in alcohol use disorder treatment
# Sham sleep feedback delivered via actigraphy biases daytime symptom reports in people with insomnia: Implications for insomnia disorder and wearable devices
# [HTML][HTML] Wearable sensors detect childhood internalizing disorders during mood induction task
# Design Considerations in Wearable Technology for Patients with Bipolar Disorder
# Characterization of depressive states in bipolar patients using wearable textile technology and instantaneous heart rate variability assessment
# [HTML][HTML] Comparison of wearable activity tracker with actigraphy for sleep evaluation and circadian rest-activity rhythm measurement in healthy young adults
# Long term activity monitoring with a wearable sensor node
# Wearable monitoring systems for psychological and physiological state assessment in a naturalistic environment
# [HTML][HTML] Effectiveness of a smartphone app with a wearable activity tracker in preventing the recurrence of mood disorders: prospective case-control study
# Wearable glove-type driver stress detection using a motion sensor
# Wearable physiological sensors reflect mental stress state in office-like situations
# Monitoring the impact of stress on the sleep patterns of pilgrims using wearable sensors
# Keep the stress away with SoDA: Stress detection and alleviation system
# Identification of suitable biomarkers for stress and emotion detection for future personal affective wearable sensors
# [HTML][HTML] Making Wearable Technology Available for Mental Healthcare through an Online Platform with Stress Detection Algorithms: The Carewear Project
# Stress Detection by Machine Learning and Wearable Sensors
# StressAware: An app for real-time stress monitoring on the amulet wearable platform
# [PDF][PDF] Stress detection and relief using wearable physiological sensors
# Detecting moments of stress from measurements of wearable physiological sensors
# Stress events detection of driver by wearable glove system
# Electrodermal activity based pre-surgery stress detection using a wrist wearable
# Pain and Stress Detection Using Wearable Sensors and Devices—A Review
# Introducing wesad, a multimodal dataset for wearable stress and affect detection
# Towards stress detection in real-life scenarios using wearable sensors: normalization factor to reduce variability in stress physiology
# Machine learning for stress detection from ECG signals in automobile drivers
# Detecting work-related stress with a wearable device
# Cognitive training and stress detection in mci frail older people through wearable sensors and machine learning
# Stress detection from multimodal wearable sensor data
# A wearable system for stress detection through physiological data analysis
# To What Extent Can We Shorten HRV Analysis in Wearable Sensing? A Case Study on Mental Stress Detection.
# Smart wearable band for stress detection
# Stress detection and management: A survey of wearable smart health devices
# Continuous stress detection using wearable sensors in real life: Algorithmic programming contest case study
# Stress detection using wearable physiological and sociometric sensors
# A comparison of wearable and stationary sensors for stress detection
# [HTML][HTML] Large-scale wearable data reveal digital phenotypes for daily-life stress detection
# [HTML][HTML] Stress detection in daily life scenarios using smart phones and wearable sensors: A survey
# Towards mental stress detection using wearable physiological sensors
# [HTML][HTML] Smartphone apps to support coordinated specialty care for prodromal and early course schizophrenia disorders: systematic review
# Differentiating dementia disease subtypes with gait analysis: feasibility of wearable sensors?
# [HTML][HTML] Clinical applications of mobile health wearable–based sleep monitoring: systematic review
# [HTML][HTML] Feasibility testing of a wearable behavioral aid for social learning in children with autism
# Systematic Review of Digital Phenotyping and Machine Learning in Psychosis Spectrum Illnesses
# mHealth for schizophrenia spectrum disorders management: A systematic review
# A systematic review of the accuracy of sleep wearable devices for estimating sleep onset
# Mobile, social, and wearable computing and the evolution of psychological practice.
# [HTML][HTML] Methodology and reporting of mobile heath and smartphone application studies for schizophrenia
# [HTML][HTML] Smartphone apps for schizophrenia: a systematic review
# [HTML][HTML] Young adults' perceptions of using wearables, social media and other technologies to detect worsening mental health: A qualitative study
# Wearable cameras are useful tools to investigate and remediate autobiographical memory impairment: A systematic PRISMA review
# … wireless system incorporating physiologic assessments and direct confirmation of digital tablet ingestions in ambulatory patients with schizophrenia or bipolar disorder
# Feasibility of popular m-health technologies for activity tracking among individuals with serious mental illness
# [HTML][HTML] … between objective behavioral features collected from mobile and wearable devices and depressive mood symptoms in patients with affective disorders …
# [HTML][HTML] From a lived event to its autobiographical memory: An ecological study using wearable camera in schizophrenia
# SleepSight: A wearables-based relapse prevention system for schizophrenia
# Real-time schizophrenia monitoring using wearable motion sensitive devices
# [HTML][HTML] Cognitive intervention targeting autobiographical memory impairment in patients with schizophrenia using a wearable camera: A proof-of-concept study
# Wearable devices and smartphones for activity tracking among people with serious mental illness
# Wearable devices and mobile technologies for supporting behavioral weight loss among people with serious mental illness
# [HTML][HTML] Using wearable technology to detect the autonomic signature of illness severity in schizophrenia
# Implementation and utility of an automated text messaging system to facilitate symptom self-monitoring and identify risk for post-traumatic stress disorder and …
# [PDF][PDF] A voice-based automated system for PTSD screening and monitoring.
# Automated Emotional Valence Prediction in Mental Health Text via Deep Transfer Learning
# An automated remote cloud-based heart rate variability monitoring system
# [HTML][HTML] Health surveys using mobile phones in developing countries: automated active strata monitoring and other statistical considerations for improving precision …
# [HTML][HTML] Therapeutic alliance with a fully automated mobile phone and web-based intervention: secondary analysis of a randomized controlled trial
# Mobile mental health: review of the emerging field and proof of concept study
# Smart homes and home health monitoring technologies for older adults: A systematic review
# [HTML][HTML] Automated remote monitoring of depression: acceptance among low-income patients in diabetes disease management
# Impact of automated calls with nurse follow-up on diabetes treatment outcomes in a Department of Veterans Affairs Health Care System: a randomized controlled trial
# Automated mental state detection for mental health care
# [HTML][HTML] Automated mobile phone–based mental health resource for homeless youth: pilot study assessing feasibility and acceptability
# Automated cognitive health assessment using smart home monitoring of complex tasks
# [HTML][HTML] … of mobile health monitoring by avoiding redundant patient reports: Prediction of depression-related symptoms and adherence problems in automated health …
# [HTML][HTML] Mobile personal health monitoring for automated classification of electrocardiogram signals in elderly
# [HTML][HTML] Ethical issues in using Twitter for population-level depression monitoring: a qualitative study
# [HTML][HTML] Development of a mobile phone app to support self-monitoring of emotional well-being: a mental health digital innovation
# Evaluating an automated mental health care system: making meaning of human–computer interaction
# Can your phone be your therapist? Young people's ethical perspectives on the use of fully automated conversational agents (chatbots) in mental health support
# Review and implementation of self-help and automated tools in mental health care
# Towards automated symptoms assessment in mental health
# Wearable eye tracking for mental health monitoring
# Devices, systems, and methods for automated monitoring enabling precision agriculture
# Early recognition of bovine respiratory disease in calves using automated continuous monitoring of cough sounds
# Towards the automated detection and occupancy estimation of primates using passive acoustic monitoring
# Multisensor-integrated organs-on-chips platform for automated and continual in situ monitoring of organoid behaviors
# Monitoring an automated system for a single failure: Vigilance and task complexity effects
# Monitoring river?channel change using terrestrial oblique digital imagery and automated digital photogrammetry
# [PDF][PDF] Automated recording of stress vocalisations as a tool to document impaired welfare in pigs
# Automated Monitoring of Panting for Feedlot Cattle: Sensor System Accuracy and Individual Variability
# Field Scanalyzer: an automated robotic field phenotyping platform for detailed crop monitoring
# Design and development of an automated and Non–contact sensing system for continuous monitoring of plant health and growth
# [HTML][HTML] Behavioural and physiological responses of laying hens to automated monitoring equipment
# Automated real-time structure health monitoring via signature pattern recognition
# Finding the adaptive sweet spot: Balancing compliance and achievement in automated stress reduction
# [HTML][HTML] Early detection of health and welfare compromises through automated detection of behavioural changes in pigs
# Accuracy of automated auscultatory blood pressure measurement during supine exercise and treadmill stress electrocardiogram-testing
# [PDF][PDF] Automated monitoring of behavioural-based animal welfare indicators
# Automated stress level monitoring in mobile setup
# The effects of group and single housing and automated animal monitoring on urinary corticosterone levels in male C57 BL/6 mice
# Reef-scale thermal stress monitoring of coral ecosystems: new 5-km global products from NOAA Coral Reef Watch
# Integrated microdevice for long-term automated perfusion culture without shear stress and real-time electrochemical monitoring of cells
# Automated stress monitoring and suitability assessment in candidate police horses
# Automated monitoring of greenhouse crops
# Advanced oxidation protein products (AOPP) for monitoring oxidative stress in critically ill patients: a simple, fast and inexpensive automated technique
# Automated stress detection using keystroke and linguistic features: An exploratory study
# Automated real-time stress monitoring of police horses using wearable technology
# Automated canopy temperature estimation via infrared thermography: A first step towards automated plant water stress monitoring
# Non-intrusive physiological monitoring for automated stress detection in human-computer interaction
# [HTML][HTML] Towards large scale automated cage monitoring–Diurnal rhythm and impact of interventions on in-cage activity of C57BL/6J mice recorded 24/7 with a non …
# [HTML][HTML] Postoperative Remote Automated Monitoring and Virtual Hospital-to-Home Care System Following Cardiac and Major Vascular Surgery: User Testing Study
# Chemotherapy-related neuropathic symptom management: a randomized trial of an automated symptom-monitoring system paired with nurse practitioner follow-up
# Remote monitoring of automated peritoneal dialysis improves personalization of dialytic prescription and patient's independence
# [HTML][HTML] Predicting the 9-year course of mood and anxiety disorders with automated machine learning: A comparison between auto-sklearn, naïve Bayes classifier …
# Automated facial video-based recognition of depression and anxiety symptom severity: cross-corpus validation
# [HTML][HTML] Automated monitoring of behaviour in zebrafish after invasive procedures
# [HTML][HTML] Impact of a mobile phone and web program on symptom and functional outcomes for people with mild-to-moderate depression, anxiety and stress: a …
# Attended and unattended automated office blood pressure measurements have better agreement with ambulatory monitoring than conventional office readings
# [HTML][HTML] Web-based fully automated self-help with different levels of therapist support for individuals with eating disorder symptoms: a randomized controlled trial
# [PDF][PDF] The promise of automated home-cage monitoring in improving translational utility of psychiatric research in rodents
# Automated monitoring of symptoms during ambulatory chemotherapy and oncology providers' use of the information: a randomized controlled clinical trial
# Identifying and monitoring cognitive deficits in clinical populations using Automated Neuropsychological Assessment Metrics (ANAM) tests
# The patient health questionnaire somatic, anxiety, and depressive symptom scales: a systematic review
# Manual and automated office measurements in relation to awake ambulatory blood pressure monitoring
# [HTML][HTML] Automated monitoring of early neurobehavioral changes in mice following traumatic brain injury
# The light spot test: Measuring anxiety in mice in an automated home-cage environment
# Impact of state anxiety on the interaction between threat monitoring and cognition
# Differential genetic regulation of motor activity and anxiety-related behaviors in mice using an automated home cage task.
# [HTML][HTML] Community attitudes to the appropriation of mobile phones for monitoring and managing depression, anxiety, and stress
# Effects of an automated telephone support system on caregiver burden and anxiety: findings from the REACH for TLC intervention study
# [HTML][HTML] Anxiety online—a virtual clinic: preliminary outcomes following completion of five fully automated treatment programs for anxiety disorders and symptoms
# Wearable Technologies for Anxious Adolescents
# Design for mental health: How socio-technological processes mediate outcome measures in a field study of a wearable anxiety app
# [HTML][HTML] Guidelines for wrist-worn consumer wearable assessment of heart rate in biobehavioral research
# More attention, less deficit: Wearable EEG-based serious game for focus improvement
# Towards a mobile and wearable system for predicting panic attacks
# iCalm: Wearable sensor and network architecture for wirelessly communicating and logging autonomic activity
# Promoting relaxation using virtual reality, olfactory interfaces and wearable EEG
# MoodWings: a wearable biofeedback device for real-time stress intervention
# i-rise: An iot-based semi-immersive affective monitoring framework for anxiety disorders
# A study on multi-class anxiety detection using wearable EEG headband
# Wearable sensor platform and mobile application for use in cognitive behavioral therapy for drug addiction and PTSD
# Stress detection using wearable physiological sensors
# Smart wearable systems: Current status and future challenges
# [HTML][HTML] Rapid detection of internalizing diagnosis in young children enabled by wearable sensors and machine learning
# A review of wearable solutions for physiological and emotional monitoring for use by people with autism spectrum disorder and their caregivers
# [HTML][HTML] Predicting Symptoms of Depression and Anxiety Using Smartphone and Wearable Data
# SCAH! RF: A Novel Wearable as a Subconscious Approach for Mitigating Anxiety Symptoms
# The inside story on wearable electronics
# Visualization of heart activity in virtual reality: A biofeedback application using wearable sensors
# Deep learning paired with wearable passive sensing data predicts deterioration in anxiety disorder symptoms across 17–18 years
# Anxiety detection using wearable monitoring
# Wearable devices as adjuncts in the treatment of anxiety?related symptoms: A narrative review of five device modalities and implications for clinical practice
# Assessing anxiety disorders using wearable devices: Challenges and future directions
# Temporal dissociation of phencyclidine: Induced locomotor and social alterations in rats using an automated homecage monitoring system–implications for the 3Rs …
# Emerging mHealth and eHealth interventions for serious mental illness: a review of the literature
# Comparison of automated home-cage monitoring systems: Emphasis on feeding behaviour, activity and spatial learning following pharmacological interventions
# Reduced overnight consolidation of procedural learning in chronic medicated schizophrenia is related to specific sleep stages
# Monitoring of plasma clozapine levels and its metabolites in refractory schizophrenic patients
# Effect of automated prescription drug monitoring program queries on emergency department opioid prescribing
# Automated ROI-based brain parcellation analysis of frontal and temporal brain volumes in schizophrenia
# Prefrontal cortex dysfunction during working memory performance in schizophrenia: reconciling discrepant findings
# [HTML][HTML] Early detection and intervention evaluation for people at risk of psychosis: multisite randomised controlled trial
# Decreased conflict-and error-related activity in the anterior cingulate cortex in subjects with schizophrenia
# [HTML][HTML] Cross-site reproducibility of social deficits in group-housed btbr mice using automated longitudinal behavioural monitoring
# Monitoring tweets for depression to detect at-risk users
# Automated detection of schizophrenia using optimal wavelet-based                         l         1 norm features extracted from single-channel EEG
# Neural correlates of the relationship between discourse coherence and sensory monitoring in schizophrenia
# Automated decision-making and big data: concerns for people with mental illness
# [HTML][HTML] Engagement with automated patient monitoring and self-management support calls: experience with a thousand chronically-ill patients
# [HTML][HTML] Monitoring and prevalence rates of metabolic syndrome in military veterans with serious mental illness
# A fully automated method for tissue segmentation and CSF-correction of proton MRSI metabolites corroborates abnormal hippocampal NAA in schizophrenia
# [HTML][HTML] Development and long-term acceptability of ExPRESS, a mobile phone app to monitor basic symptoms and early signs of psychosis relapse
# [HTML][HTML] … -activity profiles in schizophrenia using wearable and mobile technologies: development, implementation, feasibility, and acceptability of a remote monitoring …
# Automated MRI parcellation study of regional volume and thickness of prefrontal cortex (PFC) in antipsychotic?naïve schizophrenia
# Topic models for automated motor analysis in schizophrenia patients
# Automated telehealth for managing psychiatric instability in people with serious mental illness
# Blending active and passive digital technology methods to improve symptom monitoring in early psychosis
# Quantifying incoherence in speech: an automated methodology and novel application to schizophrenia
# Delta sleep deficits in schizophrenia: evidence from automated analyses of sleep data
# Automated facial expressions analysis in schizophrenia: A continuous dynamic approach
# Anterior cingulate cortex activity and impaired self-monitoring of performance in patients with schizophrenia: an event-related fMRI study
# Demonstration of automated non-adherence and service disengagement risk monitoring with active follow-up for severe mental illness
# Daily mood monitoring of symptoms using smartphones in bipolar disorder: a pilot study assessing the feasibility of ecological momentary assessment
# A systematic review of the psychometric properties, usability and clinical impacts of mobile mood-monitoring applications in young people
# The application of mHealth to mental health: opportunities and challenges
# A pilot study of an automated voice response system and nursing intervention to monitor adherence to oral chemotherapy agents
# The effect of smartphone-based monitoring on illness activity in bipolar disorder: the MONARCA II randomized controlled single-blinded trial
# [HTML][HTML] Delivering cognitive behavior therapy to young adults with symptoms of depression and anxiety using a fully automated conversational agent (Woebot): a …
# Automated bioacoustics: methods in ecology and conservation and their potential for animal welfare monitoring
# A systematic review of the effectiveness of mobile apps for monitoring and management of mental health symptoms or disorders
# Automated assessment of psychiatric disorders using speech: A systematic review
# [HTML][HTML] … nested pragmatic randomized controlled trial of a reminder system for serum lithium level monitoring in patients with mood disorder: KONOTORI study protocol
# Army research needs for automated neuropsychological tests: monitoring soldier health and performance status
# Forecasting depression in bipolar disorder
# [HTML][HTML] Daily electronic monitoring of subjective and objective measures of illness activity in bipolar disorder using smartphones–the MONARCA II trial protocol: a …
# [HTML][HTML] Smartphone-based monitoring of objective and subjective data in affective disorders: where are we and where are we going? Systematic review
# [HTML][HTML] User Perspectives of Mood-Monitoring Apps Available to Young People: Qualitative Content Analysis
# [HTML][HTML] Automated Computerized Analysis of Speechin Psychiatric Disorders
# Remote mood monitoring for adults with bipolar disorder: an explorative study of compliance and impact on mental health service use and costs
# Self-monitoring practices, attitudes, and needs of individuals with bipolar disorder: implications for the design of technologies to manage mental health
# Ecologically valid long-term mood monitoring of individuals with bipolar disorder using speech
# … and utility of an automated text messaging system to facilitate symptom self-monitoring and identify risk for post-traumatic stress disorder and depression in trauma …
# A multi-state model to improve the design of an automated system to monitor the activity patterns of patients with bipolar disorder
# Use of automated medication adherence monitoring in bipolar disorder research: pitfalls, pragmatics, and possibilities
# [HTML][HTML] Daily longitudinal self-monitoring of mood variability in bipolar disorder and borderline personality disorder
# [HTML][HTML] Electronic self-monitoring of mood using IT platforms in adult patients with bipolar disorder: a systematic review of the validity and evidence
# Open field is more sensitive than automated activity monitor in documenting ouabain-induced hyperlocomotion in the development of an animal model for bipolar …
# Semi-automated tracking: a balanced approach for self-monitoring applications
# Experiences of remote mood and activity monitoring in bipolar disorder: a qualitative study
# Mood charting and technology: new approach to monitoring patients with mood disorders
# [HTML][HTML] Evaluating depression with multimodal wristband-type wearable device: screening and assessing patient severity utilizing machine-learning
# [HTML][HTML] Wearable feedback systems for rehabilitation
# The impact and measurement of social dysfunction in late?life depression: an evaluation of current methods with a focus on wearable technology
# [HTML][HTML] Smartphone-based tracking of sleep in depression, anxiety, and psychotic disorders
# Wearable monitoring for mood recognition in bipolar disorder based on history-dependent long-term heart rate variability analysis
# Innovative ICT solutions to improve treatment outcomes for depression: The ICT4Depression project.
# [HTML][HTML] Mobile phone and wearable sensor-based mHealth approaches for psychiatric disorders and symptoms: systematic review
# Wearable sensors: opportunities and challenges for low-cost health care
# Complexity index from a personalized wearable monitoring system for assessing remission in mental health
# Nano-bio-textile sensors with mobile wireless platform for wearable health monitoring of neurological and cardiovascular disorders
# Wearable EEG-based real-time system for depression monitoring
# Wearable cardiorespiratory monitoring employing a multimodal digital patch stethoscope: estimation of ECG, PEP, LVETand respiration using a 55 mm single-lead …
# An intelligent healthcare monitoring framework using wearable sensors and social networking data
# [HTML][HTML] Wearable digital sensors to identify risks of postpartum depression and personalize psychological treatment for adolescent mothers: protocol for a mixed …
# Tracking depression dynamics in college students using mobile phone and wearable sensing
# [HTML][HTML] Flexible graphene photodetectors for wearable fitness monitoring
# A wearable health monitoring system for posttraumatic stress disorder
# [HTML][HTML] Wearable technology for high-frequency cognitive and mood assessment in major depressive disorder: longitudinal observational study
# Wearable technology to assess bradykinesia and immobility in patients with severe depression undergoing electroconvulsive therapy: A pilot study
# Rapid anxiety and depression diagnosis in young children enabled by wearable sensors and machine learning
# Identifying ketamine responses in treatment-resistant depression using a wearable forehead EEG
# [HTML][HTML] Relationship Between Major Depression Symptom Severity and Sleep Collected Using a Wristband Wearable Device: Multicenter Longitudinal Observational …
# Issues in wearable computing for medical monitoring applications: a case study of a wearable ECG monitoring device
# Smartphone-centred wearable sensors network for monitoring patients with bipolar disorder
# A comparative study of engagement in mobile and wearable health monitoring for bipolar disorder
# Wearable wellness monitoring using ecg and accelerometer data
# Wearable sensors and machine learning diagnose anxiety and depression in young children
# [HTML][HTML] Monitoring Changes in Depression Severity Using Wearable and Mobile Sensors
# Mobile and wearable technology for monitoring depressive symptoms in children and adolescents: A scoping review

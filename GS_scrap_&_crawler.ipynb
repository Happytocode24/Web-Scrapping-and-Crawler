# %%
import requests
from bs4 import BeautifulSoup
user_input=input("Enter Keyword")
for i in range(3):
    print(i)
    google_search= requests.get("https://scholar.google.co.in/scholar?start="+str(i)+user_input)
    soup=BeautifulSoup(google_search.content,'html.parser')
    #print(soup.prettify())
    for resource  in soup.select('[data-lid]'):
        #print(resource)
        print(resource.select('h3')[0].get_text())
        print(resource.select('a')[0]['href'])
        print(item.select('.gs_a')[0].get_text())
        print(item.select('.gs_rs')[0].get_text())
        print("----------------")
# Out:
# Enter Keyword0&q=Wearable for anxiety disorders
# 0
# Assessing anxiety disorders using wearable devices: Challenges and future directions
# https://www.mdpi.com/2076-3425/9/3/50/pdf
# AN Antle, ES McLaren, H Fiedler… - Proceedings of the …, 2019 - dl.acm.org
# … To address this challenge, we developed version 2.0 of Mind-Full, a wearable, mobile
# neurofeedback system, designed to teach young … INTRODUCTION Anxiety disorders are among
# the most common mental health issues in childhood and the first to emerge – affecting about …
#
# ----------------
# Wearable sensors: opportunities and challenges for low-cost health care
# https://dspace.mit.edu/bitstream/handle/1721.1/69031/Fletcher-2010-Wearable%20sensors_%20Op.pdf?sequence=2&isAllowed=y
# AN Antle, ES McLaren, H Fiedler… - Proceedings of the …, 2019 - dl.acm.org
# … To address this challenge, we developed version 2.0 of Mind-Full, a wearable, mobile
# ...
